# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Define the headers to mimic a browser request
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
}

# Amazon search URL
url = 'https://www.amazon.in/s?k=iphone+16pro+max&crid=3A240ODA26YCO&sprefix=ip%2Caps%2C235&ref=nb_sb_ss_ts-doa-p_2_2'

# Send a GET request
response = requests.get(url, headers=headers)

# List to hold the data
data = []

# Check the status code
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find all products on the page
    products = soup.find_all('div', {'data-component-type': 's-search-result'})

    for product in products:
        # Extract product title
        title = product.h2.a.text.strip()

        # Extract product link
        link = 'https://www.amazon.in' + product.h2.a['href']

        # Extract product price
        price = product.find('span', 'a-price-whole')
        price = price.text.strip() if price else 'N/A'


        # Extract ratings
        rating = product.find('span', 'a-icon-alt')
        rating = rating.text.strip() if rating else 'N/A'


        # Append data to the list
        data.append([title, link, price, rating])

    # Create a DataFrame from the data
    df = pd.DataFrame(data, columns=['Title', 'Link', 'Price', 'Rating'])

    # Save the DataFrame as a CSV file
    amazon_df = pd.DataFrame.from_dict(data)
    df.to_csv('amazon_iphone_data.csv', index=False)
    print("Data saved to amazon_iphone_data.csv")

else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
amazon_df
# Out:
# Data saved to amazon_iphone_data.csv
#                                                     0  \
# 0   Apple iPhone 16 Pro Max (256 GB) - White Titanium
# 1   Apple iPhone 16 Pro Max (256 GB) - Black Titanium
# 2     Apple iPhone 16 Pro (256 GB) - Natural Titanium
# 3   Apple iPhone 16 Pro Max (256 GB) - White Titanium
# 4      Apple iPhone 16 Pro (128 GB) - Desert Titanium
# 5   Apple iPhone 16 Pro Max (256 GB) - Desert Tita...
# 6       Apple iPhone 16 Pro (512 GB) - White Titanium
# 7   Apple iPhone 15 Pro Max (256 GB) - Black Titanium
# 8                     Apple iPhone 16 (128 GB) - Teal
# 9               Apple iPhone 16 Plus (128 GB) - White
# 10  Fire-Boltt Ninja Call Pro Plus 46.48mm (1.83 i...
# 11  Ambrane Qi2 & Magsafe 15W Wireless Charger wit...
# 12      Apple iPhone 16 Pro (128 GB) - White Titanium
# 13     Apple iPhone 16 Pro (512 GB) - Desert Titanium
# 14               Apple iPhone 15 Plus (256 GB) - Pink
# 15                   Apple iPhone 16 (128 GB) - Black
# 16             Apple iPhone 16 (128 GB) - Ultramarine
# 17                     Apple iPhone 13 (128GB) - Blue
# 18  Apple iPhone 15 Pro Max (256 GB) - Natural Tit...
# 19  BEVY Compatible with Black Titanium Iphone 16 ...
# 20  PowerUP 3-in-1 Wireless Charger for iPhone, Ai...
# 21  eLzzi Magnetic Guard Designed for iPhone 16 Pr...
#
#                                                     1         2  \
# 0   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...  1,44,900
# 1   https://www.amazon.in/Apple-iPhone-Pro-Max-256...  1,44,900
# 2   https://www.amazon.in/Apple-iPhone-16-Pro-256/...  1,29,900
# 3   https://www.amazon.in/Apple-iPhone-Pro-Max-256...  1,44,900
# 4   https://www.amazon.in/Apple-iPhone-16-Pro-128/...  1,19,900
# 5   https://www.amazon.in/Apple-iPhone-Pro-Max-256...       N/A
# 6   https://www.amazon.in/Apple-iPhone-16-Pro-512/...  1,49,900
# 7   https://www.amazon.in/Apple-iPhone-Pro-Max-256...  1,31,900
# 8   https://www.amazon.in/Apple-iPhone-16-128-GB/d...    79,900
# 9   https://www.amazon.in/Apple-iPhone-16-Plus-128...    89,900
# 10  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...       999
# 11  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...     2,399
# 12  https://www.amazon.in/Apple-iPhone-16-Pro-128/...  1,19,900
# 13  https://www.amazon.in/Apple-iPhone-16-Pro-512/...  1,49,900
# 14  https://www.amazon.in/Apple-iPhone-15-Plus-256...    89,900
# 15  https://www.amazon.in/Apple-iPhone-16-128-GB/d...    79,900
# 16  https://www.amazon.in/Apple-iPhone-16-128-Ultr...    79,900
# 17  https://www.amazon.in/Apple-iPhone-13-128GB-Bl...    42,999
# 18  https://www.amazon.in/Apple-iPhone-Pro-Max-256...  1,34,900
# 19  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...       269
# 20  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...     3,390
# 21  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...       399
#
#                      3
# 0   5.0 out of 5 stars
# 1   4.1 out of 5 stars
# 2   3.5 out of 5 stars
# 3   5.0 out of 5 stars
# 4   3.5 out of 5 stars
# 5   4.2 out of 5 stars
# 6   3.5 out of 5 stars
# 7   4.4 out of 5 stars
# 8   4.4 out of 5 stars
# 9   4.1 out of 5 stars
# 10  4.1 out of 5 stars
# 11  5.0 out of 5 stars
# 12  3.5 out of 5 stars
# 13  3.5 out of 5 stars
# 14  4.6 out of 5 stars
# 15  4.4 out of 5 stars
# 16  4.4 out of 5 stars
# 17  4.5 out of 5 stars
# 18  4.4 out of 5 stars
# 19  5.0 out of 5 stars
# 20                 N/A
# 21  4.6 out of 5 stars
